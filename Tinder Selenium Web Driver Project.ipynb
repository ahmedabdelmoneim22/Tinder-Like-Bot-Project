# %%
print("""Tinder Selenium Webdriver Project""")
# Out:
# Tinder Selenium Webdriver Project

# %%
#>>Webdriver module provides A Programming Interface to Control Web Browsers such as Chrome, Firefox, Safari, etc
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import ElementClickInterceptedException, NoSuchElementException
from time import sleep
from selenium.webdriver.common.by import By

# %%
print("Hello")
# Initialize Chrome WebDriver.
driver = webdriver.Chrome()
# Sign in Tinder | Dating, Make Friends & Meet New People.
driver.get("https://tinder.com")
sleep(5)
#Log in>>rightClick>>Copy>>Copy XPath;
#>>//*[@id="q-856107901"]/div/div[1]/div/main/div[1]/div/div/div/div/header/div/div[2]/div[2]/a;
login_button = driver.find_element(By.XPATH,'//*[@id="q-856107901"]/div/div[1]/div/main/div[1]/div/div/div/div/header/div/div[2]/div[2]/a')
login_button.click()
sleep(5)
#>>//*[@id="q1710478319"]/div/div/div/div[1]/div/div/div[2]/div[2]/span/div[2]/button;Must '' with "";
login_facebook = driver.find_element(By.XPATH,'//*[@id="q1710478319"]/div/div/div/div[1]/div/div/div[2]/div[2]/span/div[2]/button')
login_facebook.click()
sleep(5)
#>>is Utilizing Selenium WebDriver to Handle Multiple Browser Windows or Tabs.
base_window = driver.window_handles[0]
fb_login_window = driver.window_handles[1]
driver.switch_to.window(fb_login_window)
print(driver.title)
sleep(10)
#>>Find Element By XPATH>>To Input Email;
email_Login = driver.find_element(By.XPATH,'//*[@id="email"]')
#>>Input Your Email>>send your Email;
email_Login.send_keys("********************")
#>>Find Element By XPATH>>To Input Password;
password_login = driver.find_element(By.XPATH,'//*[@id="pass"]')
password_login.send_keys("*****************")
password_login.send_keys(Keys.ENTER)
driver.switch_to.window(base_window)
print(driver.title)
sleep(10)
allow_location_button = driver.find_element(By.XPATH,'//*[@id="q1710478319"]/div/div[1]/div/div/div[3]/button[1]')
allow_location_button.click()
sleep(5)
notifications_button = driver.find_element(By.XPATH,'//*[@id="q1710478319"]/div/div/div/div/div[3]/button[1]')
notifications_button.click()
sleep(10)
#like_button = driver.find_element(By.XPATH,
#'//*[@id="q-856107901"]/div/div[1]/div/main/div[1]/div/div/div[1]/div[1]/div/div[3]/div/div[4]/button')
#like_button.click()
i=3
for n in range(100):
    sleep(1)
    
    try:
        print("called")
        like_button = driver.find_element(By.XPATH,f'//*[@id="q-856107901"]/div/div[1]/div/main/div[1]/div/div/div[1]/div[1]/div/div[{i}]/div/div[4]/button')
        like_button.click()
        i=3 + 1
    except ElementClickInterceptedException:
        try:
            match_popup = driver.find_element(By.CSS_SELECTOR,".itsAMatch a")
            match_popup.click()
        except NoSuchElementException:
            sleep(2)
#//*[@id="q-856107901"]/div/div[1]/div/main/div[1]/div/div/div[1]/div[1]/div/div[3]/div/div[4]/button
#//*[@id="q-856107901"]/div/div[1]/div/main/div[1]/div/div/div[1]/div[1]/div/div[4]/div/div[4]/button
driver.quit()
#//*[@id="q-856107901"]/div/div[1]/div/main/div[1]/div/div/div[1]/div[1]/div/div[3]/div/div[4]/button
#cookies = driver.find_element(By,'//*[@id="content"]/div/div[2]/div/div/div[1]/button')
#cookies.click()
#sleep(5)
#I_Accept = driver.find_element(By.XPATH,'//*[@id="q1710478319"]/div/div[2]/div/div/div[1]/div[1]/button')
#I_Accept.click()
#sleep(5)
#allow_location = driver.find_element(By.XPATH,'//*[@id="q1710478319"]/div/div[1]/div/div/div[3]/button[1]')
#allow_location.click()
#sleep(5)
#n_me = driver.find_element(By.XPATH,'//*[@id="q1710478319"]/div/div[1]/div/div/div[3]/button[1]')
#n_me.click()
#//*[@id="q1710478319"]/div/div[1]/div/div/div[3]/button[1]
#//*[@id="q1710478319"]/div/div[1]/div/div/div[3]/button[1]
#//*[@id="q1710478319"]/div/div[1]/div/div/div[3]/button[1]
"""
for n in range(100):
    sleep(1)
    try:
        print("called")
        like_button = driver.find_element_by_xpath(
            '//*[@id="content"]/div/div[1]/div/main/div[1]/div/div/div[1]/div/div[2]/div[4]/button')
        like_button.click()
    except ElementClickInterceptedException:
        try:
            match_popup = driver.find_element_by_css_selector(".itsAMatch a")
            match_popup.click()
        except NoSuchElementException:
            sleep(2)

driver.quit()
"""
# Out:
# Hello
# Facebook
# Tinder | Dating, Make Friends & Meet New People
# called
# called
# called
# called
# called
# called
# called
# called
# called
# called
# called
# called
# called
# called
# called
# called
# called
# called
# called
# called
# called
# called
# called
# called
# called
# called
# called
# called
# called
# called
# called
# called
# called
# called
# called
# called
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15700\170548355.py in <module>
#      48     try:
#      49         print("called")
# ---> 50         like_button = driver.find_element(By.XPATH,f'//*[@id="q-856107901"]/div/div[1]/div/main/div[1]/div/div/div[1]/div[1]/div/div[{i}]/div/div[4]/button')
#      51         like_button.click()
#      52         i=3 + 1
#
# ...
